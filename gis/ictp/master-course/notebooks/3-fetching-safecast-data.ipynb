# %% [markdown]
# ### ICTP-IAEA WORKSHOOP ON ENVIRONMENTAL MAPPING: Mobilising	Trust	in Measurements	and	Engaging Scientific Citizenry, Trieste, March 2017
# ---

# %% [markdown]
# # III. Fetching data from Safecast API with Python

# %%
[{lat: 34, lon: 35, val: 12},
{lat: 34, lon: 35, val: 12},
 
]

# %%
import pandas as pd
import requests

# %%
# Building the url as a long string in one go
url = "https://api.safecast.org/measurements.json?"\
      "distance=100000&"\
      "longitude=141.0337&"\
      "captured_before=2012-04-10&"\
      "latitude=37.4218&"\
      "per_page=2000&"\
      "captured_after=2011-03-10"

# %%
url
# Out:
# 'https://api.safecast.org/measurements.json?distance=100000&longitude=141.0337&captured_before=2012-04-10&latitude=37.4218&per_page=2000&captured_after=2011-03-10'

# %%
# More advanced but cleaner way to generate the url
params = {'distance': 100000, 'latitude': 37.4218, 'longitude': 141.0337,
          'captured_after': '2011-03-10', 'captured_before': '2012-04-10',
          'per_page': 20000}
basis_url = 'https://api.safecast.org/measurements.json?'
url = basis_url + '&'.join(['%s=%s' % (key, value) for (key, value) in params.items()])

# %%
# Import requests package
import requests

# Package the request, send the request and catch the response: r
r = requests.get(url)

json_data = r.json()

# %%
json_data
# Out:
# [{u'captured_at': u'2012-01-18T02:32:50.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15500999,
#   u'latitude': 37.414865,
#   u'location_name': None,
#   u'longitude': 141.028495,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 20283.0},
#  {u'captured_at': u'2012-01-18T02:32:45.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15500998,
#   u'latitude': 37.414991666667,
#   u'location_name': None,
#   u'longitude': 141.028215,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 19713.0},
#  {u'captured_at': u'2012-01-18T02:32:55.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501000,
#   u'latitude': 37.414816666667,
#   u'location_name': None,
#   u'longitude': 141.02856833333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 20667.0},
#  {u'captured_at': u'2012-01-18T02:33:05.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501002,
#   u'latitude': 37.414786666667,
#   u'location_name': None,
#   u'longitude': 141.02861166667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 21206.0},
#  {u'captured_at': u'2012-01-18T02:33:10.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501003,
#   u'latitude': 37.414776666667,
#   u'location_name': None,
#   u'longitude': 141.02862166667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 21220.0},
#  {u'captured_at': u'2012-01-18T02:33:00.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501001,
#   u'latitude': 37.414791666667,
#   u'location_name': None,
#   u'longitude': 141.02858833333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 20916.0},
#  {u'captured_at': u'2012-01-18T02:33:15.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501004,
#   u'latitude': 37.41476,
#   u'location_name': None,
#   u'longitude': 141.02864333333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 20809.0},
#  {u'captured_at': u'2012-01-18T02:38:10.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501063,
#   u'latitude': 37.414698333333,
#   u'location_name': None,
#   u'longitude': 141.02872,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 20432.0},
#  {u'captured_at': u'2012-01-18T02:38:05.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501062,
#   u'latitude': 37.414696666667,
#   u'location_name': None,
#   u'longitude': 141.02872,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 20504.0},
#  {u'captured_at': u'2012-01-18T02:38:20.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501065,
#   u'latitude': 37.414696666667,
#   u'location_name': None,
#   u'longitude': 141.02872,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 20339.0},
#  {u'captured_at': u'2012-01-18T02:38:15.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501064,
#   u'latitude': 37.414696666667,
#   u'location_name': None,
#   u'longitude': 141.02872,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 20394.0},
#  {u'captured_at': u'2012-01-18T02:38:25.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501066,
#   u'latitude': 37.414696666667,
#   u'location_name': None,
#   u'longitude': 141.02872,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 20243.0},
#  {u'captured_at': u'2012-01-18T02:37:25.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501054,
#   u'latitude': 37.414696666667,
#   u'location_name': None,
#   u'longitude': 141.02871666667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 20717.0},
#  {u'captured_at': u'2012-01-18T02:38:00.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501061,
#   u'latitude': 37.414695,
#   u'location_name': None,
#   u'longitude': 141.02872,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 20630.0},
#  {u'captured_at': u'2012-01-18T02:37:45.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501058,
#   u'latitude': 37.414695,
#   u'location_name': None,
#   u'longitude': 141.02872,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 20629.0},
#  {u'captured_at': u'2012-01-18T02:37:55.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501060,
#   u'latitude': 37.414695,
#   u'location_name': None,
#   u'longitude': 141.02872,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 20647.0},
#  {u'captured_at': u'2012-01-18T02:37:50.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15
50.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501023,
#   u'latitude': 37.41466,
#   u'location_name': None,
#   u'longitude': 141.02870666667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 19808.0},
#  {u'captured_at': u'2012-01-18T02:41:14.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501100,
#   u'latitude': 37.41464,
#   u'location_name': None,
#   u'longitude': 141.02874166667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 17521.0},
#  {u'captured_at': u'2012-01-18T02:41:09.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501099,
#   u'latitude': 37.41464,
#   u'location_name': None,
#   u'longitude': 141.028735,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 17956.0},
#  {u'captured_at': u'2012-01-18T02:41:19.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501101,
#   u'latitude': 37.41456,
#   u'location_name': None,
#   u'longitude': 141.02876833333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 17048.0},
#  {u'captured_at': u'2012-01-18T02:32:35.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15500996,
#   u'latitude': 37.415236666667,
#   u'location_name': None,
#   u'longitude': 141.02744333333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 17846.0},
#  {u'captured_at': u'2012-01-18T02:48:33.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501188,
#   u'latitude': 37.414888333333,
#   u'location_name': None,
#   u'longitude': 141.02805833333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 21439.0},
#  {u'captured_at': u'2012-01-18T02:48:28.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501187,
#   u'latitude': 37.414685,
#   u'location_name': None,
#   u'longitude': 141.02842833333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 20293.0},
#  {u'captured_at': u'2012-01-18T02:48:38.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501189,
#   u'latitude': 37.415041666667,
#   u'location_name': None,
#   u'longitude': 141.02770666667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 22156.0},
#  {u'captured_at': u'2012-01-18T02:32:30.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15500995,
#   u'latitude': 37.415391666667,
#   u'location_name': None,
#   u'longitude': 141.02705833333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 17618.0},
#  {u'captured_at': u'2012-01-18T02:48:23.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501186,
#   u'latitude': 37.414465,
#   u'location_name': None,
#   u'longitude': 141.02876333333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 19244.0},
#  {u'captured_at': u'2012-01-18T02:48:43.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501190,
#   u'latitude': 37.41516,
#   u'location_name': None,
#   u'longitude': 141.02739,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 22276.0},
#  {u'captured_at': u'2012-01-18T02:48:48.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501191,
#   u'latitude': 37.41528,
#   u'location_name': None,
#   u'longitude': 141.027095,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 22783.0},
#  {u'captured_at': u'2012-01-18T02:32:25.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15500994,
#   u'latitude': 37.415523333333,
#   u'location_name': None,
#   u'longitude': 141.02662833333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 17070.0},
#  {u'captured_at': u'2012-01-18T02:41:24.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501102,
#   u'latitude': 37.414311666667,
#   u'location_name': None,
#   u'longitude': 141.028795,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 16565.0},
#  {u'captured_at': u'2012-01-18T02:48:53.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501192,
#   u'latitude': 37.41543,
#   u'location_name': None,
#   u'longitude': 141.02666,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 23156.0},
#  {u'captured_at': u'2012-01-18T02:48:18.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501185,
#   u'latitude': 37.414156666667,
#   u'location_name': None,
#   u'longitude': 141.02894333333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 18389.0},
#  {u'captured_at': u'2012-01-18T02:32:20.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15500993,
#   u'latitude': 37.415625,
#   u'location_name': None,
#   u'longitude': 141.026295,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 16166.0},
#  {u'captured_at': u'2012-01-18T02:48:58.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501193,
#   u'latitude': 37.41562,
#   u'location_name': None,
#   u'longitude': 141.02625333333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 23702.0},
#  {u'captured_at': u'2012-01-18T02:32:15.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15500992,
#   u'latitude': 37.415696666667,
#   u'location_name': None,
#   u'longitude': 141.02608,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 14991.0},
#  {u'captured_at': u'2012-01-18T02:49:03.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501194,
#   u'latitude': 37.415798333333,
#   u'location_name': None,
#   u'longitude': 141.02582833333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 24282.0},
#  {u'captured_at': u'2012-01-18T02:32:10.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15500991,
#   u'latitude': 37.415848333333,
#   u'location_name': None,
#   u'longitude': 141.02571833333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 13931.0},
#  {u'captured_at': u'2012-01-18T02:30:26.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15500970,
#   u'latitude': 37.418115,
#   u'location_name': None,
#   u'longitude': 141.02377333333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 7653.0},
#  {u'captured_at': u'2012-01-18T02:30:21.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15500969,
#   u'latitude': 37.418133333333,
#   u'location_name': None,
#   u'longitude': 141.02374,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 7282.0},
#  {u'captured_at': u'2012-01-18T02:41:29.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501103,
#   u'latitude': 37.413966666667,
#   u'location_name': None,
#   u'longitude': 141.02880333333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 16083.0},
#  {u'captured_at': u'2012-01-18T02:32:05.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15500990,
#   u'latitude': 37.415938333333,
#   u'location_name': None,
#   u'longitude': 141.02553666667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 13663.0},
#  {u'captured_at': u'2012-01-18T02:30:31.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15500971,
#   u'latitude': 37.418006666667,
#   u'location_name': None,
#   u'longitude': 141.02378833333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 7790.0},
#  {u'captured_at': u'2012-01-18T02:30:16.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15500968,
#   u'latitude': 37.418251666667,
#   u'location_name': None,
#   u'longitude': 141.02363666667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 7133.0},
#  {u'captured_at': u'2012-01-18T02:30:36.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15500972,
#   u'latitude': 37.41792,
#   u'location_name': None,
#   u'longitude': 141.02380833333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 7862.0},
#  {u'captured_at': u'2012-01-18T02:50:58.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501217,
#   u'latitude': 37.418001666667,
#   u'location_name': None,
#   u'longitude': 141.02375833333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
# ...
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 570.0},
#  {u'captured_at': u'2011-12-17T23:03:54.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14891098,
#   u'latitude': 37.42999,
#   u'location_name': None,
#   u'longitude': 141.008485,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 5677.0},
#  {u'captured_at': u'2012-02-11T03:10:04.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15556183,
#   u'latitude': 37.430903333333,
#   u'location_name': None,
#   u'longitude': 141.00897666667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 4434.0},
#  {u'captured_at': u'2012-02-11T03:10:04.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 17579060,
#   u'latitude': 37.43090333333334,
#   u'location_name': None,
#   u'longitude': 141.00897666666665,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 3,
#   u'value': 4434.0},
#  {u'captured_at': u'2011-11-08T05:14:41.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14475887,
#   u'latitude': 37.431025,
#   u'location_name': None,
#   u'longitude': 141.00904666667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 1395.0},
#  {u'captured_at': u'2011-11-08T05:14:36.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14475886,
#   u'latitude': 37.430426666667,
#   u'location_name': None,
#   u'longitude': 141.008705,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 1972.0},
#  {u'captured_at': u'2012-01-18T02:26:06.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15500918,
#   u'latitude': 37.426105,
#   u'location_name': None,
#   u'longitude': 141.00700333333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 1721.0},
#  {u'captured_at': u'2011-09-24T03:29:25.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14033731,
#   u'latitude': 37.429953333333,
#   u'location_name': None,
#   u'longitude': 141.00845,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 768.0},
#  {u'captured_at': u'2011-12-15T04:18:31.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14866037,
#   u'latitude': 37.40308,
#   u'location_name': None,
#   u'longitude': 141.01987666667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 10996.0},
#  {u'captured_at': u'2011-12-15T03:53:52.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14865742,
#   u'latitude': 37.443446666667,
#   u'location_name': None,
#   u'longitude': 141.031365,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 505.0},
#  {u'captured_at': u'2011-10-05T03:13:51.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14082062,
#   u'latitude': 37.43006,
#   u'location_name': None,
#   u'longitude': 141.00850166667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 935.0},
#  {u'captured_at': u'2011-10-29T03:47:19.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14251089,
#   u'latitude': 37.428968333333,
#   u'location_name': None,
#   u'longitude': 141.00798166667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 977.0},
#  {u'captured_at': u'2012-01-14T01:21:10.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15254120,
#   u'latitude': 37.433121666667,
#   u'location_name': None,
#   u'longitude': 141.01044333333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 1469.0},
#  {u'captured_at': u'2011-12-08T01:53:53.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14753695,
#   u'latitude': 37.433096666667,
#   u'location_name': None,
#   u'longitude': 141.01042333333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 672.0},
#  {u'captured_at': u'2012-02-11T03:10:14.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15556185,
#   u'latitude': 37.432648333333,
#   u'location_name': None,
#   u'longitude': 141.01009,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 2937.0},
#  {u'captured_at': u'2012-02-11T03:10:14.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 17579068,
#   u'latitude': 37.43264833333333,
#   u'location_name': None,
#   u'longitude': 141.01009000000002,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 3,
#   u'value': 2937.0},
#  {u'captured_at': u'2012-01-07T01:52:36.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15153195,
#   u'latitude': 37.43002,
#   u'location_name': None,
#   u'longitude': 141.008475,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 4230.0},
#  {u'captured_at': u'2011-10-29T03:46:44.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14251081,
#   u'latitude': 37.433388333333,
#   u'location_name': None,
#   u'longitude': 141.01064666667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 759.0},
#  {u'captured_at': u'2011-09-24T01:32:52.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14032340,
#   u'latitude': 37.432991666667,
#   u'location_name': None,
#   u'longitude': 141.01034,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 1047.0},
#  {u'captured_at': u'2011-11-05T00:55:45.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14315677,
#   u'latitude': 37.430105,
#   u'location_name': None,
#   u'longitude': 141.00851333333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 1133.0},
#  {u'captured_at': u'2012-01-07T01:52:57.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15153199,
#   u'latitude': 37.433203333333,
#   u'location_name': None,
#   u'longitude': 141.010495,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 1305.0},
#  {u'captured_at': u'2011-10-29T03:47:09.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14251086,
#   u'latitude': 37.429763333333,
#   u'location_name': None,
#   u'longitude': 141.00833666667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 866.0},
#  {u'captured_at': u'2011-09-24T01:32:32.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14032336,
#   u'latitude': 37.430113333333,
#   u'location_name': None,
#   u'longitude': 141.00851333333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 2238.0},
#  {u'captured_at': u'2011-11-10T03:54:10.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14463111,
#   u'latitude': 37.430385,
#   u'location_name': None,
#   u'longitude': 141.00865666667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 1990.0},
#  {u'captured_at': u'2011-10-29T03:47:14.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14251087,
#   u'latitude': 37.429361666667,
#   u'location_name': None,
#   u'longitude': 141.00814,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 915.0},
#  {u'captured_at': u'2011-12-18T01:10:05.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14892609,
#   u'latitude': 37.433268333333,
#   u'location_name': None,
#   u'longitude': 141.01053666667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 757.0},
#  {u'captured_at': u'2012-01-14T01:20:50.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15254116,
#   u'latitude': 37.430048333333,
#   u'location_name': None,
#   u'longitude': 141.00847166667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 4528.0},
#  {u'captured_at': u'2011-11-08T01:57:24.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14477083,
#   u'latitude': 37.429891666667,
#   u'location_name': None,
#   u'longitude': 141.00839166667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 738.0},
#  {u'captured_at': u'2011-11-10T03:54:30.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14463115,
#   u'latitude': 37.433095,
#   u'location_name': None,
#   u'longitude': 141.01039833333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 749.0},
#  {u'captured_at': u'2011-12-18T12:47:11.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14894685,
#   u'latitude': 37.426101666667,
#   u'location_name': None,
#   u'longitude': 141.00696666667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 7188.0},
#  {u'captured_at': u'2011-11-24T01:05:30.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15119345,
#   u'latitude': 37.432843333333,
#   u'location_name': None,
#   u'longitude': 141.01020333333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 810.0},
#  {u'captured_at': u'2011-11-24T01:05:30.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15143156,
#   u'latitude': 37.432843333333,
#   u'location_name': None,
#   u'longitude': 141.01020333333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 810.0},
#  {u'captured_at': u'2011-09-24T03:29:35.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14033733,
#   u'latitude': 37.429236666667,
#   u'location_name': None,
#   u'longitude': 141.00806666667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 861.0},
#  {u'captured_at': u'2011-12-08T01:54:13.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14753699,
#   u'latitude': 37.430425,
#   u'location_name': None,
#   u'longitude': 141.00865833333,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 696.0},
#  {u'captured_at': u'2012-01-18T02:57:12.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501292,
#   u'latitude': 37.430348333333,
#   u'location_name': None,
#   u'longitude': 141.008615,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 1510.0},
#  {u'captured_at': u'2011-10-05T03:13:46.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14082061,
#   u'latitude': 37.4297,
#   u'location_name': None,
#   u'longitude': 141.00827166667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 930.0},
#  {u'captured_at': u'2011-11-24T01:05:15.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15143153,
#   u'latitude': 37.430551666667,
#   u'location_name': None,
#   u'longitude': 141.00871166667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 2052.0},
#  {u'captured_at': u'2011-11-24T01:05:15.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15119342,
#   u'latitude': 37.430551666667,
#   u'location_name': None,
#   u'longitude': 141.00871166667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 2052.0},
#  {u'captured_at': u'2012-01-18T02:57:32.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15501296,
#   u'latitude': 37.432621666667,
#   u'location_name': None,
#   u'longitude': 141.01002,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 955.0},
#  {u'captured_at': u'2011-12-17T09:41:12.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14963038,
#   u'latitude': 37.433461666667,
#   u'location_name': None,
#   u'longitude': 141.010655,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 714.0},
#  {u'captured_at': u'2011-12-18T01:10:50.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14892618,
#   u'latitude': 37.430198333333,
#   u'location_name': None,
#   u'longitude': 141.00852,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 848.0},
#  {u'captured_at': u'2011-11-08T05:14:31.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14475885,
#   u'latitude': 37.429921666667,
#   u'location_name': None,
#   u'longitude': 141.00837666667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 2798.0},
#  {u'captured_at': u'2012-01-18T02:25:16.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 15500908,
#   u'latitude': 37.429436666667,
#   u'location_name': None,
#   u'longitude': 141.00814,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 831.0},
#  {u'captured_at': u'2011-09-24T03:29:40.000Z',
#   u'channel_id': None,
#   u'device_id': None,
#   u'devicetype_id': None,
#   u'height': None,
#   u'id': 14033734,
#   u'latitude': 37.428851666667,
#   u'location_name': None,
#   u'longitude': 141.00787666667,
#   u'original_id': None,
#   u'sensor_id': None,
#   u'station_id': None,
#   u'unit': u'cpm',
#   u'user_id': 1,
#   u'value': 895.0},
#  ...]

# %%
df = pd.DataFrame(json_data)

# %%
df.head()
# Out:
#                 captured_at channel_id device_id devicetype_id height  \
# 0  2012-01-18T02:32:50.000Z       None      None          None   None
# 1  2012-01-18T02:32:45.000Z       None      None          None   None
# 2  2012-01-18T02:32:55.000Z       None      None          None   None
# 3  2012-01-18T02:33:05.000Z       None      None          None   None
# 4  2012-01-18T02:33:10.000Z       None      None          None   None
#
#          id   latitude location_name   longitude original_id sensor_id  \
# 0  15500999  37.414865          None  141.028495        None      None
# 1  15500998  37.414992          None  141.028215        None      None
# 2  15501000  37.414817          None  141.028568        None      None
# 3  15501002  37.414787          None  141.028612        None      None
# 4  15501003  37.414777          None  141.028622        None      None
#
#   station_id unit  user_id    value
# 0       None  cpm        1  20283.0
# 1       None  cpm        1  19713.0
# 2       None  cpm        1  20667.0
# 3       None  cpm        1  21206.0
# 4       None  cpm        1  21220.0

# %%
df.dropna(inplace=True)

# %%
df.shape

# %%
# Using pandas to get measurements by user
df.groupby(by='user_id').size()

# %%
df.to_csv('data/safecast_from_api.csv')

# %% [markdown]
# ## A word on Big data

# %%
f = 'data/safecast_big_data.csv'    # Path to file containing the table

# A quick look at first 5 rows
data_iter = pd.read_csv(f, chunksize=5)
next(data_iter)
# Out:
#    Unnamed: 0               captured_at  channel_id  device_id  devicetype_id  \
# 0           0  2012-01-18T02:32:50.000Z         NaN        NaN            NaN
# 1           1  2012-01-18T02:32:45.000Z         NaN        NaN            NaN
# 2           2  2012-01-18T02:32:55.000Z         NaN        NaN            NaN
# 3           3  2012-01-18T02:33:05.000Z         NaN        NaN            NaN
# 4           4  2012-01-18T02:33:10.000Z         NaN        NaN            NaN
#
#    height        id   latitude  location_name   longitude  original_id  \
# 0     NaN  15500999  37.414865            NaN  141.028495          NaN
# 1     NaN  15500998  37.414992            NaN  141.028215          NaN
# 2     NaN  15501000  37.414817            NaN  141.028568          NaN
# 3     NaN  15501002  37.414787            NaN  141.028612          NaN
# 4     NaN  15501003  37.414777            NaN  141.028622          NaN
#
#    sensor_id  station_id unit  user_id    value
# 0        NaN         NaN  cpm        1  20283.0
# 1        NaN         NaN  cpm        1  19713.0
# 2        NaN         NaN  cpm        1  20667.0
# 3        NaN         NaN  cpm        1  21206.0
# 4        NaN         NaN  cpm        1  21220.0

# %%
next(data_iter)
# Out:
#    Unnamed: 0               captured_at  channel_id  device_id  devicetype_id  \
# 5           5  2012-01-18T02:33:00.000Z         NaN        NaN            NaN
# 6           6  2012-01-18T02:33:15.000Z         NaN        NaN            NaN
# 7           7  2012-01-18T02:38:10.000Z         NaN        NaN            NaN
# 8           8  2012-01-18T02:38:15.000Z         NaN        NaN            NaN
# 9           9  2012-01-18T02:38:05.000Z         NaN        NaN            NaN
#
#    height        id   latitude  location_name   longitude  original_id  \
# 5     NaN  15501001  37.414792            NaN  141.028588          NaN
# 6     NaN  15501004  37.414760            NaN  141.028643          NaN
# 7     NaN  15501063  37.414698            NaN  141.028720          NaN
# 8     NaN  15501064  37.414697            NaN  141.028720          NaN
# 9     NaN  15501062  37.414697            NaN  141.028720          NaN
#
#    sensor_id  station_id unit  user_id    value
# 5        NaN         NaN  cpm        1  20916.0
# 6        NaN         NaN  cpm        1  20809.0
# 7        NaN         NaN  cpm        1  20432.0
# 8        NaN         NaN  cpm        1  20394.0
# 9        NaN         NaN  cpm        1  20504.0

# %%
# Some counts:
#   - Total nb. of measurements
#   - Nb. of measurements by user_id

# Re-initialize iterator
data_iter = pd.read_csv(f, chunksize=1000)

nb_lines = 0
counts_by_user = {}

for chunk in data_iter:
    nb_lines += len(chunk)  
    for entry in chunk['user_id']:
        if entry in counts_by_user.keys():
            counts_by_user[entry] += 1
        else:
            counts_by_user[entry] = 1

# %%
counts_by_user

# %% [markdown]
# ### Exercise

# %% [markdown]
# Load from Safecast API:
#
# * first `1000` measurements
# * taken between `2011-03-10` and `2017-03-08``
# * `10km` around `Trieste`

# %%
# Tip: To get latitude and longitude coordinates for Trieste use Google geocoder:
import geocoder
#g = geocoder.google('Trieste, Italy')
g = geocoder.google('Cotonou')
g.latlng
# Out:
# [6.3702928, 2.3912362]
